# %% [markdown]
# ## Instalación de modulos

# %% [markdown]
# ## Librerías

# %% [markdown]
# ## Carga de Datos

# %% [markdown]
# ## SARIMA

# %% [markdown]
# ## Prophet

# %% [markdown]
# ## Neural Prophet

# %% [markdown]
# ## Orbit

# %% [markdown]
# ## Temporal Fussion Transform
